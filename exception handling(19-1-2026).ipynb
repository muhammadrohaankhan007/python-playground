# %%
num_1=int(input("enter the num 1"))
num_2=int(input("enter the num2"))
print(num_1/num_2)
# Out:
# enter the num 1 2
# enter the num2 0
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 num_1=int(input("enter the num 1"))
#       2 num_2=int(input("enter the num2"))
# ----> 3 print(num_1/num_2)
#
# ZeroDivisionError: division by zero

# %%
try:
    num_1=int(input("enter the num 1"))
    num_2=int(input("enter the num2"))
    print(num_1/num_2)
except:
    print("jani zero error a raha hai")
# Out:
# enter the num 1 2
# enter the num2 21
# 0.09523809523809523

# %%
num_1=int(input("enter the num 1"))
num_2=int(input("enter the num2"))
print(num_1/num_2)
# Out:
# enter the num 1 ndnd
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 num_1=int(input("enter the num 1"))
#       2 num_2=int(input("enter the num2"))
#       3 print(num_1/num_2)
#
# ValueError: invalid literal for int() with base 10: 'ndnd'

# %%
try:
    num_1=int(input("enter the num 1"))
    num_2=int(input("enter the num2"))
    print(num_1/num_2)
except ZeroDivisionError:
    print("jani zero error a raha hai")
except ValueError:
    print("text value error agaya")
# Out:
# enter the num 1 djdjd
# text value error agaya

# %%
try:
    num1=int(input("enter num1"))
    num2=int(input("enter num2"))
    print(num1/num2)
except ZeroDivisionError:
    print("zero division error")
except ValueError:
    print("value error agaya")
# Out:
# enter num1 dnfnf
# value error agaya

# %%
try:
    age=18
    if age>19:
    print("cnic lekr ahh chote")
    else:
    print("jao dafa ho")
except IndentationError:
        print("error")
# Out:
#   Cell In[18], line 4
#     print("cnic lekr ahh chote")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 3

# %%
try:
    print('sdd')
except SyntaxError:
    print("error")
# Out:
# sdd

# %%
num_1=int(input("enter the num 1"))
num_2=input("enter the num2")

print(num_1-num_2)
# Out:
# enter the num 1 3
# enter the num2 2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 4
#       1 num_1=int(input("enter the num 1"))
#       2 num_2=input("enter the num2")
# ----> 4 print(num_1-num_2)
#
# TypeError: unsupported operand type(s) for -: 'int' and 'str'

# %%
try:
    num_1=int(input("enter the num 1"))
    num_2=input("enter the num2")
    print(num_1/num_2)
except TypeError:
    print("type error araha hai")
# Out:
# enter the num 1 2
# enter the num2 1
# type error araha hai

# %%
try:
    import ubaid
except ModuleNotFoundError:
    print("error arsha")
# Out:
# error arsha

# %%
try:
    import rohaan
except ModuleNotFoundError:
    print("error arsha")
# Out:
# error arsha

# %%
try:
    num_1=int(input("enter the num 1"))
    num_2=int(input("enter the num2"))
    print(num_1/num_2)
except Exception:
    print(f"{Exception} error a raha")
# Out:
# enter the num 1 vvh
# <class 'Exception'> error a raha

# %%
try:
    num_1=int(input("enter the num 1"))
    num_2=int(input("enter the num2"))
    print(num_1/num_2)
except Exception as e:
    print(f" error a raha jo ke hai {e}")
# Out:
# enter the num 1 33
# enter the num2 0
#  error a raha jo ke hai division by zero

# %%
try: 
    num_1=int(input("enter the num 1"))
    num_2=int(input("enter the num2"))
    print(num_1/num_2)  
except Exception as e:
    print(f"error hai issme {e}" )
# Out:
# enter the num 1 hh
# error hai issme invalid literal for int() with base 10: 'hh'

# %%
try:
    num_1=int(input("enter the num 1"))
    num_2=int(input("enter the num2"))
    print(num_1*num_2)  
except Exception as error:
    print(f"Error: {error}")
# Out:
# enter the num 1 0
# enter the num2 2
# 0

# %%
age-int(input("enter the age"))
if age>19:
    raise Exception("AgeError")
# Out:
# enter the age 22

# %%
try:
    age=int(input("enter the age:"))
    if age>19:
        raise Exception("AgeError")
except Exception as e:
    print(f"{e}")
# Out:
# enter the age: 24
# AgeError

# %%
age=int(input("enter the age:"))
if age>19:
    print("Age error")
else:
    print("ajao jani")
# Out:
# enter the age: 34
# Age error

# %%
try:
    age=int(input("enter the age:"))
    if age>19:
        raise Exception("AgeError")
except Exception as e:
    print(f"{e}")

# %%
user_name=input("enter username:").lower()
if user_name=="admin":
    raise Exception("UserNameError")
# Out:
# enter username: e;f

# %%
try:
   user_name=input("enter username:").lower()
   if user_name=="admin":
      raise Exception("UserNameError")
except Exception as e:
    print(e)
# Out:
# enter username: admin
# UserNameError

# %%
class UserNameError(Exception):
    pass

# %%
try:
   user_name=input("enter username:").lower()
   if user_name=="admin":
      raise UserNameError("User Name Error")
except UserNameError as e:
    print(e)
# Out:
# enter username: admin
# User Name Error

# %%
try:
   user_name=input("enter username:").lower()
   if user_name=="admin":
      raise UserNameError("User Name is invalid as per our guidelines")
except UserNameError as e:
    print(f"Error : {e}")
# Out:
# enter username: admin
# Error : User Name is invalid as per our guidelines

# %% [markdown]
# file Read Write i/O stream

# %%
num_1
# Out:
# 0

# %%
user_name
# Out:
# 'admin'

# %%
f=open("myfile.txt")
print(f.read())

# %%
num1=int(input("enter the number 1: "))
num2=int(input("enter the number 2: "))
print(num1/num2)
# Out:
# enter the number 1:  2
