# %%
employee={"email":"muhammadrohaan@gmail.com",
          "name":"rohaan"}
print(employee["name"])
# Out:
# rohaan

# %%
employee["email"]="amna@gmail.com"

# %%
employee
# Out:
# {'email': 'amna@gmail.com', 'name': 'rohaan'}

# %%
character={"ship":"titanic",
           "language":"animal",
            "drivers":"kernel"}

# %%
del character["ship"]

# %%
character
# Out:
# {'language': 'animal', 'drivers': 'kernel'}

# %%
character["name"]="jani"

# %%
character
# Out:
# {'language': 'animal', 'drivers': 'kernel', 'name': 'jani'}

# %%
brand=input("What brand: ")
if brand =="outfitters":
    color=input("what color ya want: ")
    if color=="black":
        size=input("what size ya want?")
        if size == "medium":
            price=int(input("Enter price"))
            if price >=2000:
                print("here ya go, tysm for shopping with us!")
            else:
                print("sorry, ngl thats a lowball offer:(")
        else:
            print(f"sorry, we don't have {size}")
    else:
        print(f"we don't have that {color}")
else:
    print(f"sorry, we don't have {brand}")
# Out:
# What brand:  outfitters
# what color ya want:  black
# what size ya want? medium
# Enter price 300
# sorry, ngl thats a lowball offer:(

# %% [markdown]
# grading system

# %%
###### name=input("Enter name: ")
roll=input("enter roll number: ")
Class=input("enter class: ")

english=int(input("Enter english marks: "))
urdu=int(input("Enter urdu marks: "))
maths=int(input("Enter maths marks: "))
science=int(input("Enter science marks: "))
islamiat=int(input("Enter islamiat marks: "))

total=english+urdu+maths+science+islamiat
percentage=round(total/500 *100,2)
result=None
grade=None

if english >= 50:
    if urdu >= 50:
        if maths >= 50:
            if science >= 50:
                if islamiaat >= 50:
                    result="pass"
                else:
                    result="fail"
            else:
                result="fail"
        else:
            result="fail"
    else:
        result="fail"
else:
    result="fail"

if result=="pass":
    if percentage >= 90 :
        grade="A+"
    elif percentage >=80:
        grade="A"
    elif percentage >= 70:
        grade="B"
    elif percentage >= 60:
        grade="C"
    elif percentage >= 50:
        grade="D"
    else:
        grade="F"

print(f"""
=============================
         Marksheet
=============================

 Student:{name}
 roll number: {roll}
 Class : {Class}

------------------------------
 English : {english}
 Urdu : {urdu}
 Maths : {maths}
 Science : {science}
 Islamiat : {islamiat}
-------------------------------
 Grade : {grade}
 Percentage : {percentage}
 Total Marks : {total}
-------------------------------
      End! """)
# Out:
# enter roll number:  40
# enter class:  nrn
# Enter english marks:  rjr\
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 5
#       2 roll=input("enter roll number: ")
#       3 Class=input("enter class: ")
# ----> 5 english=int(input("Enter english marks: "))
#       6 urdu=int(input("Enter urdu marks: "))
#       7 maths=int(input("Enter maths marks: "))
#
# ValueError: invalid literal for int() with base 10: 'rjr\\'

# %%
git init
# Out:
#   Cell In[53], line 1
#     git init
#         ^
# SyntaxError: invalid syntax
