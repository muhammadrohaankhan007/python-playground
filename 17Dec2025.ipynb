# %%
name="hello, my name is rohaan"

# %% [markdown]
# name.capitalize()

# %%
name.capitalize()
# Out:
# 'Rohaan'

# %%
name.title()
# Out:
# 'Rohaan'

# %%
name.title()
# Out:
# 'Rohaan'

# %%
name.title()
# Out:
# 'Hello, My Name Is Rohaan'

# %%
name.capitalize()
# Out:
# 'Hello, my name is rohaan'

# %%
name.find('a')
# Out:
# 11

# %%
name.split("a")
# Out:
# ['hello, my n', 'me is roh', '', 'n']

# %%
"a".join['hello, my n', 'me is roh', '', 'n']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 "a".join['hello, my n', 'me is roh', '', 'n']
#
# TypeError: 'builtin_function_or_method' object is not subscriptable

# %%
name.replace('hello','hey')
# Out:
# 'hey, my name is rohaan'

# %%
students=["ali","ahmed","muhammad","shaheer","sohaib","amna","yasir","rohaan"]
students[1:3]
# Out:
# ['ahmed', 'muhammad']

# %%
students[0:1]
# Out:
# ['ali']

# %%
students[7:2:-2]
# Out:
# ['rohaan', 'amna', 'shaheer']

# %%
numbers=[12,34,23,54,67,78,567,23,1,0,2]
numbers.append(101)
print(numbers)
# Out:
# [12, 34, 23, 54, 67, 78, 567, 23, 1, 0, 2, 101]

# %%
numbers.insert(5,"hello")
numbers
# Out:
# [12, 34, 23, 54, 67, 'hello', 78, 567, 23, 1, 0, 2, 101]

# %%
lucky_numbers=[7,9,99]

# %%
numbers+lucky_numbers
# Out:
# [12, 34, 23, 54, 67, 'hello', 78, 567, 23, 1, 0, 2, 101, 7, 9, 99]
