# %%
print("Multiple If elif elif elif")
marks=int(input("Ente marks: "))
grade=None
if marks>=90:
    grade="A+"
elif marks>=80:
    grade="A"
elif marks >= 70:
    garde="B"
elif marks >= 60:
     grade="C"
elif marks >=50:
    grade="D"
else:
    grade="F"
print(f"Grade: ", grade)
# Out:
# Multiple If elif elif elif
# Ente marks:  3
# Grade:  F

# %%
1-2: Toodler
2-12: Kid
12-19: Teenager
20-30: Young
31 - 60: adult
60: onwardss: senior citizen

# %%
age=int(input("Enter age: "))
name=None
if age==0 and age <=2:
    name="Toodler"
elif age>=2 and age <= 12:
    name="Kid"
elif age >= 12 and age <= 19:
    name="Teenager"
elif age >= 20 and age <= 30:
     name="Young"
elif age >=31 and age <= 60:
    name="adult"
else:
    name="senior citizen"
print(f"Name:", name)
# Out:
# Enter age:  34
# Name: adult

# %%
#Nested Ifs

# %%
card=input("do you have a STudent Id card: ").lower()
if card == "yes":

    fee=input("have you paid the fee: ").lower()
    if fee=="paid":

        assignment=input("have you finished the assignment: ").lower()
        if assignment=="done":
             print("you can sit in the class")
        else:
            print("if you dont have done assignment, you cannot sit in the class")
    else:
        print("if you don't submit the fee, you cannot sit in the class") 
else:
    print("you cannot attend the class")
# Out:
# do you have a STudent Id card:  YES
# have you paid the fee:  PAID
# have you finished the assignment:  DONE
# you can sit in the class

# %%
shirt : blue, small, outfitter, price 3000
# Out:
#   Cell In[26], line 1
#     shirt : blue, small, outfitter, price 3000
#                 ^
# SyntaxError: invalid syntax

# %%
brand=input("which brand shirt do you want: ")
if brand == "outfitters":
    pass
else:
    print(f"{brand} not avaliable")
